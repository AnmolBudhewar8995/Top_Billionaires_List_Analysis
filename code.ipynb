# %% [markdown]
# >[Importing the libraries](#scrollTo=EzYWtEWeVhjd)
#
# >[Reading data](#scrollTo=X_RqkEbSVdz8)
#
# >[Data Exploration](#scrollTo=4e52769d)
#
# >[Data Visualization](#scrollTo=51296c50)

# %% [markdown]
# # Importing the libraries

# %% [markdown]
# Importing the necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

import os

# %% [markdown]
# # Reading data

# %% [markdown]
# Reading data set from CSV file

# %%
df = pd.read_csv('data.csv')
df.head(5)
# Out:
#              Name  Rank  Year  Company Founded        Company Name  \
# 0      Bill Gates     1  1996             1975           Microsoft
# 1      Bill Gates     1  2001             1975           Microsoft
# 2      Bill Gates     1  2014             1975           Microsoft
# 3  Warren Buffett     2  1996             1962  Berkshire Hathaway
# 4  Warren Buffett     2  2001             1962  Berkshire Hathaway
#
#   Company Relationship Company Sector Company Type  Demographics Age  \
# 0              founder       Software          new                40
# 1              founder       Software          new                45
# 2              founder       Software          new                58
# 3              founder        Finance          new                65
# 4              founder        Finance          new                70
#
#   Demographics Gender  ...  Location GDP Location Region          Wealth Type  \
# 0                male  ...  8.100000e+12   North America  founder non-finance
# 1                male  ...  1.060000e+13   North America  founder non-finance
# 2                male  ...  0.000000e+00   North America  founder non-finance
# 3                male  ...  8.100000e+12   North America  founder non-finance
# 4                male  ...  1.060000e+13   North America  founder non-finance
#
#   Wealth Worth In Billions Wealth How Category  Wealth How From Emerging  \
# 0                     18.5         New Sectors                      True
# 1                     58.7         New Sectors                      True
# 2                     76.0         New Sectors                      True
# 3                     15.0      Traded Sectors                      True
# 4                     32.3      Traded Sectors                      True
#
#    Wealth How Industry  Wealth How Inherited Wealth How Was Founder  \
# 0  Technology-Computer         not inherited                   True
# 1  Technology-Computer         not inherited                   True
# 2  Technology-Computer         not inherited                   True
# 3             Consumer         not inherited                   True
# 4             Consumer         not inherited                   True
#
#   Wealth How Was Political
# 0                     True
# 1                     True
# 2                     True
# 3                     True
# 4                     True
#
# [5 rows x 22 columns]

# %% [markdown]
# # Data Exploration

# %% [markdown]
# Calculating the total of missing value in each column

# %%
df.isna().sum()
# Out:
# Name                         0
# Rank                         0
# Year                         0
# Company Founded              0
# Company Name                38
# Company Relationship        46
# Company Sector              23
# Company Type                36
# Demographics Age             0
# Demographics Gender         33
# Location Citizenship         0
# Location Country Code        0
# Location GDP                 0
# Location Region              0
# Wealth Type                 22
# Wealth Worth In Billions     0
# Wealth How Category          1
# Wealth How From Emerging     0
# Wealth How Industry          1
# Wealth How Inherited         0
# Wealth How Was Founder       0
# Wealth How Was Political     0
# dtype: int64

# %% [markdown]
# The code fills missing values in specific columns of the DataFrame df with the mode (most frequent value) of each respective column using the fillna method.

# %%
df['Demographics Gender'].fillna(df['Demographics Gender'].mode()[0], inplace=True)
df['Wealth Type'].fillna(df['Wealth Type'].mode()[0], inplace=True)
df['Wealth How Category'].fillna(df['Wealth How Category'].mode()[0], inplace=True)
df['Wealth How Industry'].fillna(df['Wealth How Industry'].mode()[0], inplace=True)
df['Company Name'].fillna(df['Company Name'].mode()[0], inplace=True)
df['Company Relationship'].fillna(df['Company Relationship'].mode()[0], inplace=True)
df['Company Sector'].fillna(df['Company Sector'].mode()[0], inplace=True)
df['Company Type'].fillna(df['Company Type'].mode()[0], inplace=True)

# %% [markdown]
# Printing the information of data frame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2614 entries, 0 to 2613
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Name                      2614 non-null   object
#  1   Rank                      2614 non-null   int64
#  2   Year                      2614 non-null   int64
#  3   Company Founded           2614 non-null   int64
#  4   Company Name              2614 non-null   object
#  5   Company Relationship      2614 non-null   object
#  6   Company Sector            2614 non-null   object
#  7   Company Type              2614 non-null   object
#  8   Demographics Age          2614 non-null   int64
#  9   Demographics Gender       2614 non-null   object
#  10  Location Citizenship      2614 non-null   object
#  11  Location Country Code     2614 non-null   object
#  12  Location GDP              2614 non-null   float64
#  13  Location Region           2614 non-null   object
#  14  Wealth Type               2614 non-null   object
#  15  Wealth Worth In Billions  2614 non-null   float64
#  16  Wealth How Category       2614 non-null   object
#  17  Wealth How From Emerging  2614 non-null   bool
#  18  Wealth How Industry       2614 non-null   object
#  19  Wealth How Inherited      2614 non-null   object
#  20  Wealth How Was Founder    2614 non-null   bool
#  21  Wealth How Was Political  2614 non-null   bool
# dtypes: bool(3), float64(2), int64(4), object(13)
# memory usage: 395.8+ KB

# %% [markdown]
# The code filters the DataFrame df to select rows where the value in the 'Demographics Gender' column is 'male'.

# %%
df[df['Demographics Gender'] == 'male']
# Out:
#                 Name  Rank  Year  Company Founded  \
# 0         Bill Gates     1  1996             1975
# 1         Bill Gates     1  2001             1975
# 2         Bill Gates     1  2014             1975
# 3     Warren Buffett     2  1996             1962
# 4     Warren Buffett     2  2001             1962
# ...              ...   ...   ...              ...
# 2609     Wu Chung-Yi  1565  2014             1991
# 2610        Wu Xiong  1565  2014             1999
# 2611       Yang Keng  1565  2014                0
# 2612   Zdenek Bakala  1565  2014             1994
# 2613     Zhu Wenchen  1565  2014             1999
#
#                          Company Name Company Relationship  \
# 0                           Microsoft              founder
# 1                           Microsoft              founder
# 2                           Microsoft              founder
# 3                  Berkshire Hathaway              founder
# 4                  Berkshire Hathaway              founder
# ...                               ...                  ...
# 2609                           Tingyi             investor
# 2610  Biostime International Holdings                owner
# 2611                    Blue Ray Corp             chairman
# 2612                   Patria Finance              founder
# 2613       Furen Pharmaceutical Group             chairman
#
#           Company Sector Company Type  Demographics Age Demographics Gender  \
# 0               Software          new                40                male
# 1               Software          new                45                male
# 2               Software          new                58                male
# 3                Finance          new                65                male
# 4                Finance          new                70                male
# ...                  ...          ...               ...                 ...
# 2609  beverages and food          new                55                male
# 2610      infant formula          new                 0                male
# 2611         real estate          new                53                male
# 2612                coal          new                53                male
# 2613     pharmaceuticals          new                48                male
#
#       ...  Location GDP Location Region               Wealth Type  \
# 0     ...  8.100000e+12   North America       founder non-finance
# 1     ...  1.060000e+13   North America       founder non-finance
# 2     ...  0.000000e+00   North America       founder non-finance
# 3     ...  8.100000e+12   North America       founder non-finance
# 4     ...  1.060000e+13   North America       founder non-finance
# ...   ...           ...             ...                       ...
# 2609  ...  0.000000e+00       East Asia                 executive
# 2610  ...  0.000000e+00       East Asia                 executive
# 2611  ...  0.000000e+00       East Asia         self-made finance
# 2612  ...  0.000000e+00          Europe  privatized and resources
# 2613  ...  0.000000e+00       East Asia                 executive
#
#      Wealth Worth In Billions Wealth How Category  Wealth How From Emerging  \
# 0                        18.5         New Sectors                      True
# 1                        58.7         New Sectors                      True
# 2                        76.0         New Sectors                      True
# 3                        15.0      Traded Sectors                      True
# 4                        32.3      Traded Sectors                      True
# ...                       ...                 ...                       ...
# 2609                      1.0      Traded Sectors                      True
# 2610                      1.0      Traded Sectors                      True
# 2611                      1.0           Financial                      True
# 2612                      1.0    Resource Related                      True
# 2613                      1.0         New Sectors                      True
#
#           Wealth How Industry  Wealth How Inherited Wealth How Was Founder  \
# 0         Technology-Computer         not inherited                   True
# 1         Technology-Computer         not inherited                   True
# 2         Technology-Computer         not inherited                   True
# 3                    Consumer         not inherited                   True
# 4                    Consumer         not inherited                   True
# ...                       ...                   ...                    ...
# 2609  Non-consumer industrial         not inherited                   True
# 2610                 Consumer         not inherited                   True
# 2611              Real Estate         not inherited                   True
# 2612        Mining and metals         not inherited                   True
# 2613       Technology-Medical         not inherited                   True
#
#      Wealth How Was Political
# 0                        True
# 1                        True
# 2                        True
# 3                        True
# 4                        True
# ...                       ...
# 2609                     True
# 2610                     True
# 2611                     True
# 2612                     True
# 2613                     True
#
# [2362 rows x 22 columns]

# %% [markdown]
# The code retrieves the unique values from the 'Demographics Gender' column in the DataFrame df.

# %%
df['Demographics Gender'].unique()
# Out:
# array(['male', 'female', 'married couple'], dtype=object)

# %% [markdown]
# The code retrieves the unique values from the 'Company Relationship' column in the DataFrame df.

# %%
df['Company Relationship'].unique()
# Out:
# array(['founder', 'founder/chairman', 'Relation', 'relation', 'CEO',
#        'chairman', 'investor', 'founder and CEO', 'founder/CEO', 'owner',
#        'chairman of management committee', 'founder and chairman',
#        'Chairman and Chief Executive Officer', 'general director',
#        'executive chairman', 'Chairman/founder', 'founder, chairman, ceo',
#        'former chairman and CEO', 'relation and chairman',
#        'investor/founder', 'partner', 'president', 'investor and  CEO',
#        'founder CEO owner', 'Chairman/shareholder', 'Vice President',
#        'chairman of the board', 'founder/relation', 'ceo', 'investor ',
#        'founder/vice chairman', 'Chairman', 'Honorary President for Life',
#        'former CEO', 'inherited', 'vice-chairman', 'owner and vice chair',
#        'founder/president', 'co-chairman', 'lawer',
#        'relation/vice chairman', 'Chairman, CEO', 'employee',
#        "head of Microsoft's application software group", 'chariman',
#        'Exectuitve Director', 'vice chairman', 'shareholder',
#        'relation and ceo', 'founder, chairwoman, ceo',
#        'founder and executive chairman', 'leadership',
#        'co-director of zinc, copper and lead',
#        'head of high-yield bond trading dept', 'owner and former CEO',
#        'relative', 'founder and ceo', 'founder, chairman',
#        'president and ceo', 'Chief Executive', 'founder and chairwoman',
#        'supervisory board or directors', 'lawyer', 'inventor',
#        'founder and executive vice chairman',
#        'Global Head of Real Estate', 'Head of Board of Directors',
#        'Vice President of Infrastructure Software', 'Vice Chairman',
#        'chairman and ceo', 'COO', 'chairwomen', 'deputy chairman',
#        'director'], dtype=object)

# %% [markdown]
# The code filters the DataFrame df to include only the rows where the value in the 'Company Relationship' column is 'owner'.

# %%
df[df['Company Relationship'] == 'owner']
# Out:
#                           Name  Rank  Year  Company Founded  \
# 158             Vladimir Lisin    53  2014             1992
# 206                Donald Bren    69  2014             1864
# 295                Donald Bren    98  2001             1864
# 332          Mikhail Prokhorov   109  2014             1993
# 420   Philippe Foriel-Destezet   138  2001             1996
# ...                        ...   ...   ...              ...
# 2532                Zadik Bino  1540  2014             1922
# 2533           Alberto Alcocer  1565  2014             1952
# 2542               Boris Mints  1565  2014             2010
# 2577           Lin Ming-Hsiung  1565  2014             1998
# 2610                  Wu Xiong  1565  2014             1999
#
#                          Company Name Company Relationship   Company Sector  \
# 158                              NLMK                owner            steel
# 206                    Irvine Company                owner      real estate
# 295                    Irvine Company                owner      real estate
# 332                    Norilsk Nickel                owner  precious metals
# 420                            Adecco                owner    HR consulting
# ...                               ...                  ...              ...
# 2532                  Paz oil company                owner              oil
# 2533       Construcciones y Contratas                owner     construction
# 2542                    O1 Properties                owner      real estate
# 2577                           Pxmart                owner           retail
# 2610  Biostime International Holdings                owner   infant formula
#
#        Company Type  Demographics Age Demographics Gender  ...  Location GDP  \
# 158         aquired                57                male  ...  0.000000e+00
# 206         aquired                81                male  ...  0.000000e+00
# 295         aquired                68                male  ...  1.060000e+13
# 332   privatization                48                male  ...  0.000000e+00
# 420         aquired                65                male  ...  1.380000e+12
# ...             ...               ...                 ...  ...           ...
# 2532            new                70                male  ...  0.000000e+00
# 2533        aquired                71                male  ...  0.000000e+00
# 2542            new                55                male  ...  0.000000e+00
# 2577  privatization                64                male  ...  0.000000e+00
# 2610            new                 0                male  ...  0.000000e+00
#
#                Location Region               Wealth Type  \
# 158                     Europe  privatized and resources
# 206              North America         self-made finance
# 295              North America         self-made finance
# 332                     Europe  privatized and resources
# 420                     Europe                 executive
# ...                        ...                       ...
# 2532  Middle East/North Africa         self-made finance
# 2533                    Europe         self-made finance
# 2542                    Europe         self-made finance
# 2577                 East Asia  privatized and resources
# 2610                 East Asia                 executive
#
#      Wealth Worth In Billions Wealth How Category  Wealth How From Emerging  \
# 158                      16.6    Resource Related                      True
# 206                      14.4           Financial                      True
# 295                       4.0           Financial                      True
# 332                      10.9           Financial                      True
# 420                       3.2  Non-Traded Sectors                      True
# ...                       ...                 ...                       ...
# 2532                      1.1           Financial                      True
# 2533                      1.0           Financial                      True
# 2542                      1.0           Financial                      True
# 2577                      1.0  Non-Traded Sectors                      True
# 2610                      1.0      Traded Sectors                      True
#
#           Wealth How Industry  Wealth How Inherited Wealth How Was Founder  \
# 158   Non-consumer industrial         not inherited                   True
# 206               Real Estate         not inherited                   True
# 295               Real Estate         not inherited                   True
# 332     Diversified financial         not inherited                   True
# 420        Retail, Restaurant         not inherited                   True
# ...                       ...                   ...                    ...
# 2532         Money Management         not inherited                   True
# 2533    Diversified financial         not inherited                   True
# 2542              Real Estate         not inherited                   True
# 2577       Retail, Restaurant         not inherited                   True
# 2610                 Consumer         not inherited                   True
#
#      Wealth How Was Political
# 158                      True
# 206                      True
# 295                      True
# 332                      True
# 420                      True
# ...                       ...
# 2532                     True
# 2533                     True
# 2542                     True
# 2577                     True
# 2610                     True
#
# [94 rows x 22 columns]

# %% [markdown]
# The code filters the DataFrame df to include only the rows where the value in the 'Company Relationship' column is 'owner' and the value in the 'Demographics Age' column is greater than 40.

# %%
df[(df['Company Relationship'] == 'owner') & (df['Demographics Age'] > 40)]
# Out:
#                           Name  Rank  Year  Company Founded  \
# 158             Vladimir Lisin    53  2014             1992
# 206                Donald Bren    69  2014             1864
# 295                Donald Bren    98  2001             1864
# 332          Mikhail Prokhorov   109  2014             1993
# 420   Philippe Foriel-Destezet   138  2001             1996
# ...                        ...   ...   ...              ...
# 2530             Wang Laisheng  1540  2014             2004
# 2532                Zadik Bino  1540  2014             1922
# 2533           Alberto Alcocer  1565  2014             1952
# 2542               Boris Mints  1565  2014             2010
# 2577           Lin Ming-Hsiung  1565  2014             1998
#
#                      Company Name Company Relationship         Company Sector  \
# 158                          NLMK                owner                  steel
# 206                Irvine Company                owner            real estate
# 295                Irvine Company                owner            real estate
# 332                Norilsk Nickel                owner        precious metals
# 420                        Adecco                owner          HR consulting
# ...                           ...                  ...                    ...
# 2530  Luxshare Precision Industry                owner  electonics components
# 2532              Paz oil company                owner                    oil
# 2533   Construcciones y Contratas                owner           construction
# 2542                O1 Properties                owner            real estate
# 2577                       Pxmart                owner                 retail
#
#        Company Type  Demographics Age Demographics Gender  ...  Location GDP  \
# 158         aquired                57                male  ...  0.000000e+00
# 206         aquired                81                male  ...  0.000000e+00
# 295         aquired                68                male  ...  1.060000e+13
# 332   privatization                48                male  ...  0.000000e+00
# 420         aquired                65                male  ...  1.380000e+12
# ...             ...               ...                 ...  ...           ...
# 2530            new                49                male  ...  0.000000e+00
# 2532            new                70                male  ...  0.000000e+00
# 2533        aquired                71                male  ...  0.000000e+00
# 2542            new                55                male  ...  0.000000e+00
# 2577  privatization                64                male  ...  0.000000e+00
#
#                Location Region               Wealth Type  \
# 158                     Europe  privatized and resources
# 206              North America         self-made finance
# 295              North America         self-made finance
# 332                     Europe  privatized and resources
# 420                     Europe                 executive
# ...                        ...                       ...
# 2530                 East Asia                 executive
# 2532  Middle East/North Africa         self-made finance
# 2533                    Europe         self-made finance
# 2542                    Europe         self-made finance
# 2577                 East Asia  privatized and resources
#
#      Wealth Worth In Billions Wealth How Category  Wealth How From Emerging  \
# 158                      16.6    Resource Related                      True
# 206                      14.4           Financial                      True
# 295                       4.0           Financial                      True
# 332                      10.9           Financial                      True
# 420                       3.2  Non-Traded Sectors                      True
# ...                       ...                 ...                       ...
# 2530                      1.1         New Sectors                      True
# 2532                      1.1           Financial                      True
# 2533                      1.0           Financial                      True
# 2542                      1.0           Financial                      True
# 2577                      1.0  Non-Traded Sectors                      True
#
#           Wealth How Industry  Wealth How Inherited Wealth How Was Founder  \
# 158   Non-consumer industrial         not inherited                   True
# 206               Real Estate         not inherited                   True
# 295               Real Estate         not inherited                   True
# 332     Diversified financial         not inherited                   True
# 420        Retail, Restaurant         not inherited                   True
# ...                       ...                   ...                    ...
# 2530      Technology-Computer         not inherited                   True
# 2532         Money Management         not inherited                   True
# 2533    Diversified financial         not inherited                   True
# 2542              Real Estate         not inherited                   True
# 2577       Retail, Restaurant         not inherited                   True
#
#      Wealth How Was Political
# 158                      True
# 206                      True
# 295                      True
# 332                      True
# 420                      True
# ...                       ...
# 2530                     True
# 2532                     True
# 2533                     True
# 2542                     True
# 2577                     True
#
# [83 rows x 22 columns]

# %% [markdown]
# The code filters the DataFrame df to include only the rows where the value in the 'Rank' column is less than 11.

# %%
df[df['Rank'] < 11]
# Out:
#                                 Name  Rank  Year  Company Founded  \
# 0                         Bill Gates     1  1996             1975
# 1                         Bill Gates     1  2001             1975
# 2                         Bill Gates     1  2014             1975
# 3                     Warren Buffett     2  1996             1962
# 4                     Warren Buffett     2  2001             1962
# 5                   Carlos Slim Helu     2  2014             1990
# 6            Oeri Hoffman and Sacher     3  1996             1896
# 7                         Paul Allen     3  2001             1975
# 8                     Amancio Ortega     3  2014             1975
# 9                       Lee Shau Kee     4  1996             1976
# 10                     Larry Ellison     4  2001             1977
# 11                    Warren Buffett     4  2014             1839
# 12                      Tsai Wan-lin     5  1996             1962
# 13            Theo and Karl Albrecht     5  2001             1913
# 14                     Larry Ellison     5  2014             1977
# 15    Walter Thomas and Raymond Kwok     6  1996             1963
# 16  Prince Alwaleed Bin Talal Alsaud     6  2001             1980
# 17                      Charles Koch     6  2014             1940
# 18                        David Koch     6  2014             1940
# 19                       Li Ka-shing     7  1996             1971
# 20                        Jim Walton     7  2001             1962
# 21                 Yoshiaki Tsutsumi     8  1996             1894
# 22                       John Walton     8  2001             1962
# 23                   Sheldon Adelson     8  2014             1952
# 24            Theo and Karl Albrecht     9  1996             1913
# 25                   S Robson Walton     9  2001             1962
# 26                    Christy Walton     9  2014             1962
# 27              Hans and Gad Rausing    10  1996             1951
# 28                      Alice Walton    10  2001             1962
# 29                      Helen Walton    10  2001             1962
# 30                        Jim Walton    10  2014             1962
#
#                   Company Name Company Relationship  \
# 0                    Microsoft              founder
# 1                    Microsoft              founder
# 2                    Microsoft              founder
# 3           Berkshire Hathaway              founder
# 4           Berkshire Hathaway              founder
# 5                       Telmex              founder
# 6         F. Hoffmann-La Roche              founder
# 7                    Microsoft              founder
# 8                         Zara              founder
# 9   Henderson Land Development     founder/chairman
# 10                      Oracle              founder
# 11          Berkshire Hathaway              founder
# 12              Lin Yuan Group              founder
# 13                        Aldi              founder
# 14                      Oracle              founder
# 15     Sun Hung Kai Properties             Relation
# 16     Kingdom Holding Company              founder
# 17             Koch industries             relation
# 18             Koch industries             relation
# 19                 Cheung king              founder
# 20                     Walmart             relation
# 21           Seibu Corporation             relation
# 22                     Walmart             relation
# 23             Las Vegas Sands              founder
# 24                   Aldi Nord             Relation
# 25                     Walmart             relation
# 26                     Walmart             relation
# 27                   Tetra Pak             relation
# 28                     Walmart             relation
# 29                     Walmart             relation
# 30                     Walmart             relation
#
#                       Company Sector   Company Type  Demographics Age  \
# 0                           Software            new                40
# 1                           Software            new                45
# 2                           Software            new                58
# 3                            Finance            new                65
# 4                            Finance            new                70
# 5                     Communications  privatization                74
# 6                    pharmaceuticals            new                 0
# 7                         technology            new                48
# 8                            Fashion            new                77
# 9                        real estate            new                68
# 10                          software            new                56
# 11                           Finance        aquired                83
# 12             banking and insurance            new                71
# 13                         groceries            new                 0
# 14                          software            new                69
# 15                       real estate            new                 0
# 16  construction/real estate/banking            new                44
# 17                      Oil refining            new                78
# 18                      Oil refining            new                73
# 19                       real estate            new                67
# 20                            retail            new                53
# 21                       real estate        aquired                61
# 22                            retail            new                55
# 23                           casinos       acquired                80
# 24                         groceries            new                 0
# 25                            retail            new                57
# 26                            retail            new                59
# 27                    food packaging            new                 0
# 28                            retail            new                52
# 29                            retail            new                81
# 30                            retail            new                66
#
#    Demographics Gender  ...  Location GDP           Location Region  \
# 0                 male  ...  8.100000e+12             North America
# 1                 male  ...  1.060000e+13             North America
# 2                 male  ...  0.000000e+00             North America
# 3                 male  ...  8.100000e+12             North America
# 4                 male  ...  1.060000e+13             North America
# 5                 male  ...  0.000000e+00             Latin America
# 6                 male  ...  3.300000e+11                    Europe
# 7                 male  ...  1.060000e+13             North America
# 8                 male  ...  0.000000e+00                    Europe
# 9                 male  ...  1.600000e+11                 East Asia
# 10                male  ...  1.060000e+13             North America
# 11                male  ...  0.000000e+00             North America
# 12                male  ...  0.000000e+00                 East Asia
# 13                male  ...  1.950000e+12                    Europe
# 14                male  ...  0.000000e+00             North America
# 15                male  ...  1.600000e+11                 East Asia
# 16                male  ...  1.830000e+11  Middle East/North Africa
# 17                male  ...  0.000000e+00             North America
# 18                male  ...  0.000000e+00             North America
# 19                male  ...  1.600000e+11                 East Asia
# 20                male  ...  1.060000e+13             North America
# 21                male  ...  4.710000e+12                 East Asia
# 22                male  ...  1.060000e+13             North America
# 23                male  ...  0.000000e+00             North America
# 24                male  ...  2.500000e+12                    Europe
# 25                male  ...  1.060000e+13             North America
# 26              female  ...  0.000000e+00             North America
# 27                male  ...  2.880000e+11                    Europe
# 28              female  ...  1.060000e+13             North America
# 29              female  ...  1.060000e+13             North America
# 30                male  ...  0.000000e+00             North America
#
#                  Wealth Type Wealth Worth In Billions Wealth How Category  \
# 0        founder non-finance                     18.5         New Sectors
# 1        founder non-finance                     58.7         New Sectors
# 2        founder non-finance                     76.0         New Sectors
# 3        founder non-finance                     15.0      Traded Sectors
# 4        founder non-finance                     32.3      Traded Sectors
# 5   privatized and resources                     72.0  Non-Traded Sectors
# 6                  inherited                     13.1         New Sectors
# 7        founder non-finance                     30.4         New Sectors
# 8        founder non-finance                     64.0  Non-Traded Sectors
# 9          self-made finance                     12.7           Financial
# 10       founder non-finance                     26.0         New Sectors
# 11       founder non-finance                     58.2      Traded Sectors
# 12         self-made finance                     12.2           Financial
# 13       founder non-finance                     25.0  Non-Traded Sectors
# 14       founder non-finance                     48.0         New Sectors
# 15                 inherited                     11.2           Financial
# 16  privatized and resources                     20.0           Financial
# 17                 inherited                     40.0           Financial
# 18                 inherited                     40.0           Financial
# 19         self-made finance                     10.6           Financial
# 20                 inherited                     18.8  Non-Traded Sectors
# 21                 inherited                      9.2           Financial
# 22                 inherited                     18.7      Traded Sectors
# 23         self-made finance                     38.0           Financial
# 24                 inherited                      9.0  Non-Traded Sectors
# 25                 inherited                     18.6  Non-Traded Sectors
# 26                 inherited                     36.7  Non-Traded Sectors
# 27                 inherited                      9.0      Traded Sectors
# 28                 inherited                     18.5  Non-Traded Sectors
# 29                 inherited                     18.5      Traded Sectors
# 30                 inherited                     34.7  Non-Traded Sectors
#
#     Wealth How From Emerging    Wealth How Industry  Wealth How Inherited  \
# 0                       True    Technology-Computer         not inherited
# 1                       True    Technology-Computer         not inherited
# 2                       True    Technology-Computer         not inherited
# 3                       True               Consumer         not inherited
# 4                       True               Consumer         not inherited
# 5                       True                  Media         not inherited
# 6                       True     Technology-Medical        3rd generation
# 7                       True    Technology-Computer         not inherited
# 8                       True     Retail, Restaurant         not inherited
# 9                       True            Real Estate         not inherited
# 10                      True    Technology-Computer         not inherited
# 11                      True               Consumer         not inherited
# 12                      True            Hedge funds         not inherited
# 13                      True     Retail, Restaurant         not inherited
# 14                      True    Technology-Computer         not inherited
# 15                      True            Real Estate                father
# 16                      True       Money Management         not inherited
# 17                      True  Diversified financial                father
# 18                      True  Diversified financial                father
# 19                      True            Real Estate         not inherited
# 20                      True     Retail, Restaurant                father
# 21                      True            Real Estate                father
# 22                      True               Consumer                father
# 23                      True            Real Estate         not inherited
# 24                      True     Retail, Restaurant                father
# 25                      True     Retail, Restaurant                father
# 26                      True     Retail, Restaurant          spouse/widow
# 27                      True               Consumer                father
# 28                      True     Retail, Restaurant                father
# 29                      True               Consumer          spouse/widow
# 30                      True     Retail, Restaurant                father
#
#    Wealth How Was Founder Wealth How Was Political
# 0                    True                     True
# 1                    True                     True
# 2                    True                     True
# 3                    True                     True
# 4                    True                     True
# 5                    True                     True
# 6                    True                     True
# 7                    True                     True
# 8                    True                     True
# 9                    True                     True
# 10                   True                     True
# 11                   True                     True
# 12                   True                     True
# 13                   True                     True
# 14                   True                     True
# 15                   True                     True
# 16                   True                     True
# 17                   True                     True
# 18                   True                     True
# 19                   True                     True
# 20                   True                     True
# 21                   True                     True
# 22                   True                     True
# 23                   True                     True
# 24                   True                     True
# 25                   True                     True
# 26                   True                     True
# 27                   True                     True
# 28                   True                     True
# 29                   True                     True
# 30                   True                     True
#
# [31 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['Name', 'Rank', 'Year', 'Company Founded', 'Company Name',
#        'Company Relationship', 'Company Sector', 'Company Type',
#        'Demographics Age', 'Demographics Gender', 'Location Citizenship',
#        'Location Country Code', 'Location GDP', 'Location Region',
#        'Wealth Type', 'Wealth Worth In Billions', 'Wealth How Category',
#        'Wealth How From Emerging', 'Wealth How Industry',
#        'Wealth How Inherited', 'Wealth How Was Founder',
#        'Wealth How Was Political'],
#       dtype='object')

# %%
# !pip install matplotlib seaborn plotly
# Out:
# Requirement already satisfied: matplotlib in e:\ml-projects\top_billionaires_list_analysis\venv\lib\site-packages (3.8.2)
# Requirement already satisfied: seaborn in e:\ml-projects\top_billionaires_list_analysis\venv\lib\site-packages (0.13.0)
# Requirement already satisfied: plotly in e:\ml-projects\top_billionaires_list_analysis\venv\lib\site-packages (5.18.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in e:\ml-projects\top_billionaires_list_analysis\venv\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in e:\ml-projects\top_billionaires_list_analysis\venv\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in e:\ml-projects\top_billionaires_list_analysis\venv\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: pillow>=8 in e:\ml-projects\top_billionaires_list_analysis\venv\lib\site-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in e:\ml-projects\top_billionaires_list_analysis\venv\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: numpy<2,>=1.21 in e:\ml-projects\top_billionaires_list_analysis\venv\lib\site-packages (from matplotlib) (1.26.2)
# Requirement already satisfied: fonttools>=4.22.0 in e:\ml-projects\top_billionaires_list_analysis\venv\lib\site-packages (from matplotlib) (4.45.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in e:\ml-projects\top_billionaires_list_analysis\venv\lib\site-packages (from matplotlib) (6.1.1)
# Requirement already satisfied: cycler>=0.10 in e:\ml-projects\top_billionaires_list_analysis\venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: contourpy>=1.0.1 in e:\ml-projects\top_billionaires_list_analysis\venv\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: zipp>=3.1.0 in e:\ml-projects\top_billionaires_list_analysis\venv\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.17.0)
# Requirement already satisfied: six>=1.5 in e:\ml-projects\top_billionaires_list_analysis\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: pandas>=1.2 in e:\ml-projects\top_billionaires_list_analysis\venv\lib\site-packages (from seaborn) (2.1.3)
# Requirement already satisfied: pytz>=2020.1 in e:\ml-projects\top_billionaires_list_analysis\venv\lib\site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in e:\ml-projects\top_billionaires_list_analysis\venv\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: tenacity>=6.2.0 in e:\ml-projects\top_billionaires_list_analysis\venv\lib\site-packages (from plotly) (8.2.3)
# WARNING: You are using pip version 21.1.1; however, version 23.3.1 is available.
# You should consider upgrading via the 'e:\ml-projects\top_billionaires_list_analysis\venv\scripts\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# # Data Visualization

# %% [markdown]
# The code creates a histogram of the distribution of billionaire ages using the 'Demographics Age' column from the DataFrame df. The histogram includes 30 bins and a kernel density estimation (kde) plot. The plot is displayed with a title, x-axis label, y-axis label, and shown using plt.show().

# %%
# Distribution of billionaire ages
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='Demographics Age', bins=30, kde=True)
plt.title('Distribution of Billionaire Ages')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# The code generates a scatter plot using the 'Demographics Age' column as the x-axis and the 'Wealth Worth In Billions' column as the y-axis. The points are colored based on the 'Company Sector' column, and the names of the billionaires are shown when hovering over the points. The plot is displayed with a title using fig.show().

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the style for Seaborn
sns.set(style="whitegrid")

# Create a scatter plot
plt.figure(figsize=(10, 6))
scatter = sns.scatterplot(data=df, x='Demographics Age', y='Wealth Worth In Billions', hue='Company Sector', palette='viridis', size='Wealth Worth In Billions')

# Set plot title and labels
plt.title('Wealth Worth vs. Age of Billionaires')
plt.xlabel('Demographics Age')
plt.ylabel('Wealth Worth In Billions')

# Display legend
scatter.legend(title='Company Sector')

# Show the plot
plt.show()

# %% [markdown]
# The code filters the DataFrame to select only the 'Company Relationship' and 'Wealth Worth In Billions' columns. It then groups the data by 'Company Relationship' and calculates the average wealth worth. A line plot is created using the company relationship categories on the x-axis and the average wealth worth on the y-axis. The plot is given a title and labels for the axes, and the x-axis labels are rotated for better readability. Finally, the plot is displayed using plt.show().

# %%
# Filter the DataFrame to include only the required columns
df_filtered = df[['Company Relationship', 'Wealth Worth In Billions']]

# Group the data by 'Company Relationship' and calculate the average wealth worth
df_grouped = df_filtered.groupby('Company Relationship').mean()

# Create the line plot
plt.plot(df_grouped.index, df_grouped['Wealth Worth In Billions'], marker='o')

# Set the plot title and labels
plt.title('Average Wealth Worth by Company Relationship')
plt.xlabel('Company Relationship')
plt.ylabel('Wealth Worth In Billions')

# Rotate the x-axis labels for better readability (optional)
plt.xticks(rotation=90, fontsize=5.5)

# Display the plot
plt.show()

# %% [markdown]
# The code calculates the correlation matrix between the columns 'Demographics Age', 'Wealth Worth In Billions', and 'Location GDP' in the DataFrame. It then creates a heatmap using seaborn, displaying the correlation values as annotations. The heatmap is given a title and displayed using plt.show().

# %%
# Calculate the correlation matrix
corr_matrix = df[['Demographics Age', 'Wealth Worth In Billions', 'Location GDP']].corr()

# Create a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# The code selects a subset of columns from the DataFrame, including 'Demographics Age', 'Wealth Worth In Billions', and 'Company Sector'. It then creates a pair plot using seaborn, where each pairwise combination of variables is plotted, with the points colored by the 'Company Sector' category. The plot is given a title and displayed using plt.show().

# %%
# Select a subset of columns for the pair plot
subset_columns = ['Demographics Age', 'Wealth Worth In Billions', 'Company Sector']

# Create a pair plot
sns.pairplot(data=df[subset_columns], hue='Company Sector')
plt.title('Pairwise Relationships')
plt.show()

# %% [markdown]
# The code creates a violin plot using seaborn to visualize the distribution of 'Wealth Worth In Billions' across different categories of 'Company Type'. The x-axis represents the 'Company Type', and the y-axis represents the 'Wealth Worth In Billions'. The plot is given a title, and the x-axis labels are rotated for better readability. The plot is displayed using plt.show().

# %%
# Violin plot showing the wealth worth by company type
plt.figure(figsize=(10, 6))
sns.violinplot(data=df, x='Company Type', y='Wealth Worth In Billions')
plt.xticks(rotation=90)
plt.title('Wealth Worth by Company Type')
plt.show()
